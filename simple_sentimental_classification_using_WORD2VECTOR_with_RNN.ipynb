# %%
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import OneHotEncoder
import random
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN, Dense
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# nltk.download('punkt')

# Sample sentiment dataset
positive_sentences = [
    "I love this movie",
    "This film is great",
    "Amazing experience",
    "I am very happy with the product",
    "The book is fantastic"
]

negative_sentences = [
    "I hate this movie",
    "This film is terrible",
    "Horrible experience",
    "I am very unhappy with the product",
    "The book is awful"
]

sentences = positive_sentences + negative_sentences
labels = [1] * len(positive_sentences) + [0] * len(negative_sentences)

# Tokenize the sentences
tokenized_sentences = [word_tokenize(sentence.lower()) for sentence in sentences]

# Build the vocabulary
vocab = set(word for sentence in tokenized_sentences for word in sentence)
vocab_size = len(vocab)

# Create word_to_index and index_to_word mappings
word_to_index = {word: idx for idx, word in enumerate(vocab)}
index_to_word = {idx: word for word, idx in word_to_index.items()}

# Prepare training data for Word2Vec (CBOW)
def generate_training_data(tokenized_sentences, word_to_index, window_size=2):
    data = []
    for sentence in tokenized_sentences:
        for i, word in enumerate(sentence):
            target = word_to_index[word]
            context = []
            for j in range(i - window_size, i + window_size + 1):
                if j != i and j >= 0 and j < len(sentence):
                    context.append(word_to_index[sentence[j]])
            data.append((context, target))
    return data

training_data = generate_training_data(tokenized_sentences, word_to_index)

# Word2Vec CBOW Model
class Word2VecCBOW:
    def __init__(self, vocab_size, embedding_dim):
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.W1 = np.random.randn(vocab_size, embedding_dim)
        self.W2 = np.random.randn(embedding_dim, vocab_size)
        
    def softmax(self, x):
        e_x = np.exp(x - np.max(x))
        return e_x / e_x.sum(axis=0)
    
    def forward_cbow(self, context_indices):
        h = np.mean(self.W1[context_indices], axis=0)
        u = np.dot(h, self.W2)
        y_pred = self.softmax(u)
        return y_pred, h
    
    def backward_cbow(self, error, h, context_indices, learning_rate):
        dW2 = np.outer(h, error)
        dW1 = np.zeros_like(self.W1)
        for context_index in context_indices:
            dW1[context_index] += np.dot(self.W2, error)
        dW1 /= len(context_indices)
        
        self.W1[context_indices] -= learning_rate * dW1[context_indices]
        self.W2 -= learning_rate * dW2

    def train_cbow(self, training_data, epochs, learning_rate):
        for epoch in range(epochs):
            loss = 0
            for context, target in training_data:
                y_pred, h = self.forward_cbow(context)
                error = y_pred.copy()
                error[target] -= 1
                self.backward_cbow(error, h, context, learning_rate)
                loss += -np.log(y_pred[target])
            if epoch % 100 == 0:
                print(f'Epoch {epoch + 1}, Loss: {loss}')

# Initialize and train the Word2Vec CBOW model
embedding_dim = 10
word2vec_cbow = Word2VecCBOW(vocab_size, embedding_dim)
word2vec_cbow.train_cbow(training_data, epochs=1000, learning_rate=0.01)

# Get word embeddings
embeddings = word2vec_cbow.W1

# Prepare data for RNN
max_length = max(len(sentence) for sentence in tokenized_sentences)
encoded_sentences = [[word_to_index[word] for word in sentence] for sentence in tokenized_sentences]
padded_sentences = pad_sequences(encoded_sentences, maxlen=max_length, padding='post')
labels = np.array(labels)

# Define the RNN model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embeddings], input_length=max_length, trainable=False))
model.add(SimpleRNN(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the RNN model
model.fit(padded_sentences, labels, epochs=100, verbose=1)

# Test the model
test_sentences = ["I love this book", "I hate this product"]
test_tokenized = [word_tokenize(sentence.lower()) for sentence in test_sentences]
# Out:
# Epoch 1, Loss: 173.7556082088693
# Epoch 101, Loss: 35.851099001477486
# Epoch 201, Loss: 22.087502682542492
# Epoch 301, Loss: 18.81803924476258
# Epoch 401, Loss: 17.69639723933672
# Epoch 501, Loss: 17.166589821632204
# Epoch 601, Loss: 16.86763031352376
# Epoch 701, Loss: 16.67892094969198
# Epoch 801, Loss: 16.550243387916986
# Epoch 901, Loss: 16.45739124175441
# Epoch 1/100
# C:\Users\arunachalam.cherma\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5000 - loss: 0.7731
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 0.7114
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6000 - loss: 0.6692
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6000 - loss: 0.6451
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6000 - loss: 0.6348
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6000 - loss: 0.6316
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6000 - loss: 0.6289
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6000 - loss: 0.6221
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6000 - loss: 0.6121
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7000 - loss: 0.6013
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8000 - loss: 0.5906
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8000 - loss: 0.5799
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9000 - loss: 0.5700
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.5611
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.5529
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9000 - loss: 0.5452
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.5378
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9000 - loss: 0.5303
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.5222
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.5144
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.5063
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9000 - loss: 0.4981
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9000 - loss: 0.4900
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9000 - loss: 0.4814
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8000 - loss: 0.4724
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8000 - loss: 0.4626
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9000 - loss: 0.4531
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9000 - loss: 0.4441
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9000 - loss: 0.4353
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9000 - loss: 0.4266
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9000 - loss: 0.4179
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9000 - loss: 0.4089
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.4002
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.3910
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3814
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.3720
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.3627
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3536
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.3445
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.3347
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.3246
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3141
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3035
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.2928
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.2818
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.2703
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.2580
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.2461
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.2348
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.2230
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.2107
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.1984
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.1866
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.1750
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.1633
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.1517
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.1403
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.1293
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1189
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1087
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0987
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0895
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0811
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0733
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0661
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0594
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0533
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0476
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0425
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0380
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0342
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0309
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0279
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0251
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0227
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0205
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0186
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0169
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0154
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0044

# %% [markdown]
# # Prediction

# %%
# Test the model
test_sentences = ["I love this book", "I hate this product"]
test_tokenized = [word_tokenize(sentence.lower()) for sentence in test_sentences]
encoded_test_sentences = [[word_to_index.get(word, 0) for word in sentence] for sentence in test_tokenized]
padded_test_sentences = pad_sequences(encoded_test_sentences, maxlen=max_length, padding='post')
predictions = model.predict(padded_test_sentences)

# Print predictions
for i, sentence in enumerate(test_sentences):
    sentiment = 'positive' if predictions[i][0] >= 0.5 else 'negative'
    print(f"Sentence: '{sentence}' - Sentiment prediction: {predictions[i][0]:.4f} ({sentiment})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Sentence: 'I love this book' - Sentiment prediction: 0.9671 (positive)
# Sentence: 'I hate this product' - Sentiment prediction: 0.0190 (negative)

# %%
tokenized_sentences
# Out:
# [['i', 'love', 'this', 'movie'],
#  ['this', 'film', 'is', 'great'],
#  ['amazing', 'experience'],
#  ['i', 'am', 'very', 'happy', 'with', 'the', 'product'],
#  ['the', 'book', 'is', 'fantastic'],
#  ['i', 'hate', 'this', 'movie'],
#  ['this', 'film', 'is', 'terrible'],
#  ['horrible', 'experience'],
#  ['i', 'am', 'very', 'unhappy', 'with', 'the', 'product'],
#  ['the', 'book', 'is', 'awful']]

# %%
padded_sentences
# Out:
# array([[ 0, 18,  1, 11,  0,  0,  0],
#        [ 1, 20, 21,  8,  0,  0,  0],
#        [13, 12,  0,  0,  0,  0,  0],
#        [ 0, 16,  5,  9, 14,  6,  2],
#        [ 6, 10, 21, 15,  0,  0,  0],
#        [ 0, 19,  1, 11,  0,  0,  0],
#        [ 1, 20, 21, 17,  0,  0,  0],
#        [ 7, 12,  0,  0,  0,  0,  0],
#        [ 0, 16,  5,  3, 14,  6,  2],
#        [ 6, 10, 21,  4,  0,  0,  0]])

# %%
vocab_size,embedding_dim
# Out:
# (22, 10)
